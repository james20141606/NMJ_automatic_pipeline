# %%
import gc, argparse, sys, os, errno
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from beakerx import *
plt.style.use('ggplot')
import seaborn as sns
sns.set()
import h5py
import os
from tqdm import tqdm_notebook as tqdm
import scipy
import sklearn
from scipy.stats import pearsonr
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/xupeng/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import gc, argparse, sys, os, errno
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from beakerx import *
plt.style.use('ggplot')
import seaborn as sns
sns.set()
import h5py
import os
from tqdm import tqdm
import scipy
import sklearn
from scipy.stats import pearsonr
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Mask1

# %%
cd /home/xupeng/projects/membrane/
# Out:
# /home/xupeng/projects/membrane

# %%
ls data/test/
# Out:
# mask1_mip1/

# %%
ls data/test/mask1_mip1
# Out:
# KK_mask1_em_export_s000.png  KK_mask1_em_export_s080.png
# KK_mask1_em_export_s001.png  KK_mask1_em_export_s081.png
# KK_mask1_em_export_s002.png  KK_mask1_em_export_s082.png
# KK_mask1_em_export_s003.png  KK_mask1_em_export_s083.png
# KK_mask1_em_export_s004.png  KK_mask1_em_export_s084.png
# KK_mask1_em_export_s005.png  KK_mask1_em_export_s085.png
# KK_mask1_em_export_s006.png  KK_mask1_em_export_s086.png
# KK_mask1_em_export_s007.png  KK_mask1_em_export_s087.png
# KK_mask1_em_export_s008.png  KK_mask1_em_export_s088.png
# KK_mask1_em_export_s009.png  KK_mask1_em_export_s089.png
# KK_mask1_em_export_s010.png  KK_mask1_em_export_s090.png
# KK_mask1_em_export_s011.png  KK_mask1_em_export_s091.png
# KK_mask1_em_export_s012.png  KK_mask1_em_export_s092.png
# KK_mask1_em_export_s013.png  KK_mask1_em_export_s093.png
# KK_mask1_em_export_s014.png  KK_mask1_em_export_s094.png
# KK_mask1_em_export_s015.png  KK_mask1_em_export_s095.png
# KK_mask1_em_export_s016.png  KK_mask1_em_export_s096.png
# KK_mask1_em_export_s017.png  KK_mask1_em_export_s097.png
# KK_mask1_em_export_s018.png  KK_mask1_em_export_s098.png
# KK_mask1_em_export_s019.png  KK_mask1_em_export_s099.png
# KK_mask1_em_export_s020.png  KK_mask1_em_export_s100.png
# KK_mask1_em_export_s021.png  KK_mask1_em_export_s101.png
# KK_mask1_em_export_s022.png  KK_mask1_em_export_s102.png
# KK_mask1_em_export_s023.png  KK_mask1_em_export_s103.png
# KK_mask1_em_export_s024.png  KK_mask1_em_export_s104.png
# KK_mask1_em_export_s025.png  KK_mask1_em_export_s105.png
# KK_mask1_em_export_s026.png  KK_mask1_em_export_s106.png
# KK_mask1_em_export_s027.png  KK_mask1_em_export_s107.png
# KK_mask1_em_export_s028.png  KK_mask1_em_export_s108.png
# KK_mask1_em_export_s029.png  KK_mask1_em_export_s109.png
# KK_mask1_em_export_s030.png  KK_mask1_em_export_s110.png
# KK_mask1_em_export_s031.png  KK_mask1_em_export_s111.png
# KK_mask1_em_export_s032.png  KK_mask1_em_export_s112.png
# KK_mask1_em_export_s033.png  KK_mask1_em_export_s113.png
# KK_mask1_em_export_s034.png  KK_mask1_em_export_s114.png
# KK_mask1_em_export_s035.png  KK_mask1_em_export_s115.png
# KK_mask1_em_export_s036.png  KK_mask1_em_export_s116.png
# KK_mask1_em_export_s037.png  KK_mask1_em_export_s117.png
# KK_mask1_em_export_s038.png  KK_mask1_em_export_s118.png
# KK_mask1_em_export_s039.png  KK_mask1_em_export_s119.png
# KK_mask1_em_export_s040.png  KK_mask1_em_export_s120.png
# KK_mask1_em_export_s041.png  KK_mask1_em_export_s121.png
# KK_mask1_em_export_s042.png  KK_mask1_em_export_s122.png
# KK_mask1_em_export_s043.png  KK_mask1_em_export_s123.png
# KK_mask1_em_export_s044.png  KK_mask1_em_export_s124.png
# KK_mask1_em_export_s045.png  KK_mask1_em_export_s125.png
# KK_mask1_em_export_s046.png  KK_mask1_em_export_s126.png
# KK_mask1_em_export_s047.png  KK_mask1_em_export_s127.png
# KK_mask1_em_export_s048.png  KK_mask1_em_export_s128.png
# KK_mask1_em_export_s049.png  KK_mask1_em_export_s129.png
# KK_mask1_em_export_s050.png  KK_mask1_em_export_s130.png
# KK_mask1_em_export_s051.png  KK_mask1_em_export_s131.png
# KK_mask1_em_export_s052.png  KK_mask1_em_export_s132.png
# KK_mask1_em_export_s053.png  KK_mask1_em_export_s133.png
# KK_mask1_em_export_s054.png  KK_mask1_em_export_s134.png
# KK_mask1_em_export_s055.png  KK_mask1_em_export_s135.png
# KK_mask1_em_export_s056.png  KK_mask1_em_export_s136.png
# KK_mask1_em_export_s057.png  KK_mask1_em_export_s137.png
# KK_mask1_em_export_s058.png  KK_mask1_em_export_s138.png
# KK_mask1_em_export_s059.png  KK_mask1_em_export_s139.png
# KK_mask1_em_export_s060.png  KK_mask1_em_export_s140.png
# KK_mask1_em_export_s061.png  KK_mask1_em_export_s141.png
# KK_mask1_em_export_s062.png  KK_mask1_em_export_s142.png
# KK_mask1_em_export_s063.png  KK_mask1_em_export_s143.png
# KK_mask1_em_export_s064.png  KK_mask1_em_export_s144.png
# KK_mask1_em_export_s065.png  KK_mask1_em_export_s145.png
# KK_mask1_em_export_s066.png  KK_mask1_em_export_s146.png
# KK_mask1_em_export_s067.png  KK_mask1_em_export_s147.png
# KK_mask1_em_export_s068.png  KK_mask1_em_export_s148.png
# KK_mask1_em_export_s069.png  KK_mask1_em_export_s149.png
# KK_mask1_em_export_s070.png  KK_mask1_em_export_s150.png
# KK_mask1_em_export_s071.png  KK_mask1_em_export_s151.png
# KK_mask1_em_export_s072.png  KK_mask1_em_export_s152.png
# KK_mask1_em_export_s073.png  KK_mask1_em_export_s153.png
# KK_mask1_em_export_s074.png  KK_mask1_em_export_s154.png
# KK_mask1_em_export_s075.png  KK_mask1_em_export_s155.png
# KK_mask1_em_export_s076.png  KK_mask1_em_export_s156.png
# KK_mask1_em_export_s077.png  KK_mask1_em_export_s157.png
# KK_mask1_em_export_s078.png  KK_mask1_em_export_s158.png
# KK_mask1_em_export_s079.png  KK_mask1_em_export_s159.png

# %%
emdata = {}
for i in tqdm(np.arange(0,100)):
    emdata[i] = scipy.misc.imread('data/test/mask1_mip1/KK_mask1_em_export_s'+'{0:03}'.format(i)+'.png')
# Out:
# 100%|██████████| 100/100 [00:33<00:00,  2.97it/s]

# %%
styles = ["white","dark",'whitegrid',"darkgrid"]
contexts = ['paper','talk','poster','notebook']
sns.set_context(contexts[0])
sns.set_style(styles[0])

# %%
uniqueind = np.unique(emdata[0].reshape(-1,3),axis=0)

# %%
row = 4
fig,ax=plt.subplots(row,2,figsize=(16,5*row))
for i in range(row):
    for j in range(2):
        #xmin, xmax, ymin, ymax = find_bounding(segdata[i*2+j])
        ax[i,j].imshow(emdata[i*2+j])

# %%
fig,ax=plt.subplots(1,figsize=(16,8))
ax.imshow(emdata[0])

# %%
for i in tqdm(np.arange(0,100)):
    print (emdata[i][:,:,0].shape)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 6021.54it/s]
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)
# (2782, 4695)

# %%
for i in tqdm(np.arange(0,100)):
    scipy.misc.imsave('data/test/mask1_mip1/all/image_'+str(i)+'.png',
                      emdata[i][:,:,0])
# Out:
# 100%|██████████| 100/100 [02:39<00:00,  1.59s/it]

# %%
#normalized_data = np.ndarray([100,5565, 9391])
with h5py.File('data/mask1/tmp.h5') as f:
    for i in tqdm(np.arange(200,300)):
        #normalized_data[i] = emdata[i][:,:,0]
            f.create_dataset(str(i),data=emdata[i][:,:,0])
# Out:
# 100%|██████████| 100/100 [00:29<00:00,  3.39it/s]

# %%
emmip0arr = np.zeros([50,5565, 9391]).astype('uint8')
with h5py.File('data/mask1/tmp.h5') as f:
    for i in tqdm(range(50)):
        emmip0arr[i] = f[str(i)][:].astype('uint8')
with h5py.File('data/mask1/mask1_em_mip0_0_50.h5') as f:
    f.create_dataset('main',data=emmip0arr,dtype=uint8)
# Out:
# 100%|██████████| 50/50 [00:25<00:00,  1.98it/s]

# %%
with h5py.File('mask1_em.h5') as f:
    f.create_dataset('main',data=normalized_data,dtype=uint8)

# %% [markdown]
# ### 8.5  resolution is important. export mip3 and 4!

# %%
ls data/mask1/mask1_mip3/
# Out:
# KK_mask1_em_export_s000.png  KK_mask1_em_export_s041.png
# KK_mask1_em_export_s001.png  KK_mask1_em_export_s042.png
# KK_mask1_em_export_s002.png  KK_mask1_em_export_s043.png
# KK_mask1_em_export_s003.png  KK_mask1_em_export_s044.png
# KK_mask1_em_export_s004.png  KK_mask1_em_export_s045.png
# KK_mask1_em_export_s005.png  KK_mask1_em_export_s046.png
# KK_mask1_em_export_s006.png  KK_mask1_em_export_s047.png
# KK_mask1_em_export_s007.png  KK_mask1_em_export_s048.png
# KK_mask1_em_export_s008.png  KK_mask1_em_export_s049.png
# KK_mask1_em_export_s009.png  KK_mask1_em_export_s050.png
# KK_mask1_em_export_s010.png  KK_mask1_em_export_s051.png
# KK_mask1_em_export_s011.png  KK_mask1_em_export_s052.png
# KK_mask1_em_export_s012.png  KK_mask1_em_export_s053.png
# KK_mask1_em_export_s013.png  KK_mask1_em_export_s054.png
# KK_mask1_em_export_s014.png  KK_mask1_em_export_s055.png
# KK_mask1_em_export_s015.png  KK_mask1_em_export_s056.png
# KK_mask1_em_export_s016.png  KK_mask1_em_export_s057.png
# KK_mask1_em_export_s017.png  KK_mask1_em_export_s058.png
# KK_mask1_em_export_s018.png  KK_mask1_em_export_s059.png
# KK_mask1_em_export_s019.png  KK_mask1_em_export_s060.png
# KK_mask1_em_export_s020.png  KK_mask1_em_export_s061.png
# KK_mask1_em_export_s021.png  KK_mask1_em_export_s062.png
# KK_mask1_em_export_s022.png  KK_mask1_em_export_s063.png
# KK_mask1_em_export_s023.png  KK_mask1_em_export_s064.png
# KK_mask1_em_export_s024.png  KK_mask1_em_export_s065.png
# KK_mask1_em_export_s025.png  KK_mask1_em_export_s066.png
# KK_mask1_em_export_s026.png  KK_mask1_em_export_s067.png
# KK_mask1_em_export_s027.png  KK_mask1_em_export_s068.png
# KK_mask1_em_export_s028.png  KK_mask1_em_export_s069.png
# KK_mask1_em_export_s029.png  KK_mask1_em_export_s070.png
# KK_mask1_em_export_s030.png  KK_mask1_em_export_s071.png
# KK_mask1_em_export_s031.png  KK_mask1_em_export_s072.png
# KK_mask1_em_export_s032.png  KK_mask1_em_export_s073.png
# KK_mask1_em_export_s033.png  KK_mask1_em_export_s074.png
# KK_mask1_em_export_s034.png  KK_mask1_em_export_s075.png
# KK_mask1_em_export_s035.png  KK_mask1_em_export_s076.png
# KK_mask1_em_export_s036.png  KK_mask1_em_export_s077.png
# KK_mask1_em_export_s037.png  KK_mask1_em_export_s078.png
# KK_mask1_em_export_s038.png  KK_mask1_em_export_s079.png
# KK_mask1_em_export_s039.png  KK_mask1_em_export_s080.png
# KK_mask1_em_export_s040.png

# %%
emdata_mip3 = {}
for i in tqdm(range(81)):
    emdata_mip3[i] = scipy.misc.imread('data/mask1/mask1_mip3/KK_mask1_em_export_s'+'{0:03}'.format(i)+'.png')
# Out:
# HBox(children=(IntProgress(value=0, max=81), HTML(value='')))

# %%
uniqueind = np.unique(emdata_mip3[0].reshape(-1,3),axis=0)

# %%
row = 2
fig,ax=plt.subplots(row,2,figsize=(16,5*row))
for i in range(row):
    for j in range(2):
        #xmin, xmax, ymin, ymax = find_bounding(segdata[i*2+j])
        ax[i,j].imshow(emdata_mip3[i*2+j])

# %%
for i in tqdm(range(301)):
    print (emdata_mip3[i].shape)
# Out:
# HBox(children=(IntProgress(value=0, max=301), HTML(value='')))
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# (706, 1234, 3)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-0f97f7ec4c70> in <module>()
#       1 for i in tqdm(range(301)):
# ----> 2     print (emdata_mip3[i].shape)
#
# KeyError: 81

# %%
emdata_mip4 = {}
for i in tqdm(range(81)):
    emdata_mip4[i] = scipy.misc.imread('data/mask1/mask1_mip4/KK_mask1_em_export_s'+'{0:03}'.format(i)+'.png')
# Out:
# HBox(children=(IntProgress(value=0, max=81), HTML(value='')))

# %%
for i in tqdm(range(81)):
    print (emdata_mip4[i].shape)
# Out:
# HBox(children=(IntProgress(value=0, max=81), HTML(value='')))
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)
# (353, 617, 3)

# %%
normalized_data = np.ndarray([81,353, 617])
for i in tqdm(range(81)):
    normalized_data[i] = emdata_mip4[i][:,:,0]
# Out:
# HBox(children=(IntProgress(value=0, max=81), HTML(value='')))

# %%
with h5py.File('data/mask1/mask1_em_mip0.h5') as f:
    f.create_dataset('main',data=normalized_data,dtype=uint8)
