# %%
import gc, argparse, sys, os, errno
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from beakerx import *
plt.style.use('ggplot')
import seaborn as sns
sns.set()
import h5py
import os
from tqdm import tqdm
import scipy
import sklearn
from scipy.stats import pearsonr
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /home/xupeng/projects/membrane/
# Out:
# /home/xupeng/projects/membrane

# %%
ls outputs/nmj0815marcodatamip0
# Out:
# volume_0.h5

# %%
with h5py.File('outputs/nmj0815marcodatamip0/volume_0.h5') as f:
    prediction = f['main'][:3]

# %%
with h5py.File('data/mask1/mask1_em_mip4.h5') as f:
    em = f['main'][:]

# %%
em.shape
# Out:
# (81, 353, 617)

# %%
prediction.shape
# Out:
# (10, 5565, 9391)

# %%
def plot(layerind):
    fig,ax=plt.subplots(1,2,figsize=(12,6))
    ax[0].imshow(prediction[layerind],cmap='gray')
    ax[1].imshow(em[layerind],cmap='gray')

# %%
for i in np.arange(40,60):
    plot(i)

# %%
def plot_(layerind):
    fig,ax=plt.subplots(1,figsize=(6,6))
    ax.imshow(prediction[layerind],cmap='gray')
    #ax[1].imshow(em[layerind],cmap='gray')

# %%
for i in np.arange(0,3):
    plot_(i)

# %%
plot_(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-792d61696a0d> in <module>()
# ----> 1 plot_(1)
#
# NameError: name 'plot_' is not defined

# %%
with h5py.File('data/train_set/marco/marco_1435_mask') as f:
    segment = f['main'][:]

# %%
imshow(segment[0],cmap='gray')

# %%
segment.shape
# Out:
# (1435, 565, 877)

# %%
em.shape
# Out:
# (301, 1413, 2469)

# %%
np.unique(segment[0])
# Out:
# array([0, 1], dtype=uint8)

# %%
with h5py.File('')
